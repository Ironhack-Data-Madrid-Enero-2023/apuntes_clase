# %% [markdown]
# # 2.2 - Web Scraping (bs4)
#
# $$$$
#
# ![scraping](images/scraping.png)
#
# $$$$
#
# Web scraping o raspado web, es una técnica utilizada mediante programas de software para extraer información de sitios web. Usualmente, estos programas simulan la navegación de un humano en la web ya sea utilizando el protocolo HTTP manualmente, o incrustando un navegador en una aplicación.
#
# El web scraping está muy relacionado con la indexación de la web, la cual indexa la información de la web utilizando un robot y es una técnica universal adoptada por la mayoría de los motores de búsqueda. Sin embargo, el web scraping se enfoca más en la transformación de datos sin estructura en la web, como el formato HTML, en datos estructurados que pueden ser almacenados y analizados en una base de datos central, en una hoja de cálculo o en alguna otra fuente de almacenamiento. Alguno de los usos del web scraping son la comparación de precios en tiendas, la monitorización de datos relacionados con el clima de cierta región, la detección de cambios en sitios webs y la integración de datos en sitios webs.
#
# En los últimos años el web scraping se ha convertido en una técnica muy utilizada dentro del sector del posicionamiento web gracias a su capacidad de generar grandes cantidades de datos para crear contenidos de calidad.
#
# Podríamos pensar que el web scraping es nuestro último recurso a falta de una API o un feed RSS. A falta de una fuente de datos, siempre podemos extraer aquello que sale por pantalla.

# %% [markdown]
# ### Extracción desde el HTML
#
# Para scrapear una página web, en primer lugar debemos conocer las estructura que tiene el HTML. Veamos la estructura básica.
#
# El HTML consiste en contenido `<etiquetado>`, es como si fueran cajas de contenido, organizado de manera jerárquica:
#
# ```
# <html>
#     <head>
#         <title>Titulo de la pagina</title>
#     </head>
#     <body>
#         <h1>Cabecera</h1>
#         <p>Parrafo</p>
#     </body>
# </html>
# ```
#
# $$$$
#
# Las etiquetas el HTML se pueden clasificar en varios grupos, dependiendo del tipo de contenido que posea. Estos son algunos ejemplos:
#
# + cabecera: `<h1>`, `<h2>`, `<h3>`, `<hgroup>`...
# + texto: `<b>`, `<p>`...
# + embebido: `<audio>`, `<img>`, `<video>`...
# + tabular: `<table>`, `<tr>`, `<td>`, `<tbody>`...
# + secciones: `<header>`, `<section>`, `<article>`...
# + metadata: `<meta>`, `<title>`, `<script>`...
#
# $$$$
#
# Las etiquetas pueden tener atributos. Por ejemplo:
#
# `<div class="text-monospace" id="name_132", href="www.example.com"> Contenido de la pagina </div>`
#
# Esta etiqueta `div` tiene los siguientes atributos:
#
# + class: atributo con valor "text-monospace". La clase no es única en la página.
# + id: atributo con valor "name_132". El id de una etiqueta la identifica de manera unívoca.
# + href: atributo con valor "www.example.com". El href suele contener el link a otra parte de la página.
#
# Siguiendo con la analogía de las cajas, si una etiqueta de HTML es una caja, los atributos serían las pegatinas pegadas en la tapa de la caja.
#
# Conociendo cual es el contenido que queremos extraer, debemos encontrar las etiquetas dentro del HTML de la página web.

# %% [markdown]
# Usaremos la herramienta **[BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)**.

# %%
# %pip install beautifulsoup4

# %%
import requests as req

from bs4 import BeautifulSoup as bs    # ambos alias son cosa mia

# %% [markdown]
# ### Ejemplos Wikipedia
#
# **[Países europeos según esperanza de vida](https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy)**

# %%
url='https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'

# %%
# usamos requests para extraer el HTML

html=req.get(url).content   # o .text

html[:1000]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of European countries by life expectancy - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled";(function(){va'

# %%
len(html)
# Out:
# 368687

# %%
# parsear


soup=bs(html, 'html.parser')

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
len(soup.find_all('table'))
# Out:
# 13

# %%
tabla=soup.find_all('table')[3]

type(tabla)
# Out:
# bs4.element.Tag

# %%
tabla.find_all('tr')[0].text.split('\n')
# Out:
# ['',
#  'Rank',
#  '',
#  'Country',
#  'Life expectancy[6]',
#  '',
#  'Influenza vaccination rate, people aged 65 and over, 2016 (%)[7]',
#  '']

# %%
filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]
# Out:
# [['Rank',
#   '',
#   'Country',
#   'Life expectancy[6]',
#   '',
#   'Influenza vaccination rate, people aged 65 and over, 2016 (%)[7]'],
#  ['1', '', '\xa0Monaco[8]', '', '89.4'],
#  ['2', '', '\xa0San Marino[9]', '', '83.4'],
#  ['3', '', '\xa0Switzerland', '83.0'],
#  ['4', '', '\xa0Spain', '82.8', '', '56%']]

# %%
final = []

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]
# Out:
# [['Rank',
#   'Country',
#   'Life expectancy[6]',
#   'Influenza vaccination rate, people aged 65 and over, 2016 (%)[7]'],
#  ['1', '\xa0Monaco[8]', '89.4'],
#  ['2', '\xa0San Marino[9]', '83.4'],
#  ['3', '\xa0Switzerland', '83.0'],
#  ['4', '\xa0Spain', '82.8', '56%']]

# %%
final = [[palabra for palabra in f if palabra!=''] for f in filas]

final[:5]
# Out:
# [['Rank',
#   'Country',
#   'Life expectancy[6]',
#   'Influenza vaccination rate, people aged 65 and over, 2016 (%)[7]'],
#  ['1', '\xa0Monaco[8]', '89.4'],
#  ['2', '\xa0San Marino[9]', '83.4'],
#  ['3', '\xa0Switzerland', '83.0'],
#  ['4', '\xa0Spain', '82.8', '56%']]

# %%
import pandas as pd


col_names = filas[0]

data = filas[1:]


df=pd.DataFrame(data, columns=col_names)

df.head()
# Out:
#   Rank           Country Life expectancy[6]        \
# 0    1         Monaco[8]                     89.4
# 1    2     San Marino[9]                     83.4
# 2    3       Switzerland               83.0  None
# 3    4             Spain               82.8
# 4    5     Liechtenstein               82.7
#
#   Influenza vaccination rate, people aged 65 and over, 2016 (%)[7]
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                                56%
# 4                                                28%

# %%
# esto es solo para pandas

df_c = pd.read_clipboard()    # ctrl+V

df_c.head()
# Out:
#    Rank        Country       Life expectancy[6] Influenza  vaccination  rate,  \
# 0     1      Monaco[8]       89.4          None      None          NaN    NaN
# 1     2            San  Marino[9]          83.4      None          NaN    NaN
# 2     3    Switzerland       83.0          None      None          NaN    NaN
# 3     4          Spain       82.8           56%      None          NaN    NaN
# 4     5  Liechtenstein       82.7           28%      None          NaN    NaN
#
#    people  aged  65  and  over,  2016  (%)[7]
# 0     NaN   NaN NaN  NaN    NaN   NaN     NaN
# 1     NaN   NaN NaN  NaN    NaN   NaN     NaN
# 2     NaN   NaN NaN  NaN    NaN   NaN     NaN
# 3     NaN   NaN NaN  NaN    NaN   NaN     NaN
# 4     NaN   NaN NaN  NaN    NaN   NaN     NaN

# %%
pd.read_clipboard()
# Out:
# Empty DataFrame
# Columns: [pd.read_clipboard()]
# Index: []

# %% [markdown]
# ### Ejemplo geolocalización por IP
#
# https://tools.keycdn.com/geo

# %% [markdown]
# **¿Dónde estoy?**

# %%
url='https://tools.keycdn.com/geo?host=2.136.116.82'

# %%
html = req.get(url).text

sopa = bs(html, 'html.parser')

# %%
sopa.find('div', id='geoResult')
# Out:
# <div class="mt-4" id="geoResult">
# <div class="bg-light medium rounded p-3">
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mb-2">Location</p> <dl class="row mb-0">
# <dt class="col-4">City</dt><dd class="col-8 text-monospace">Madrid</dd><dt class="col-4">Region</dt><dd class="col-8 text-monospace">Madrid (M)</dd><dt class="col-4">Postal code</dt><dd class="col-8 text-monospace">28006</dd><dt class="col-4">Country</dt><dd class="col-8 text-monospace">Spain (ES)</dd><dt class="col-4">Continent</dt><dd class="col-8 text-monospace">Europe (EU)</dd><dt class="col-4">Coordinates</dt><dd class="col-8 text-monospace">40.4163 (lat) / -3.6934 (long)</dd><dt class="col-4">Time</dt><dd class="col-8 text-monospace">2023-02-07 11:53:03 (Europe/Madrid)</dd> </dl>
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mt-4 mb-2">Network</p>
# <dl class="row mb-0">
# <dt class="col-4">IP address</dt><dd class="col-8 text-monospace">2.136.116.82</dd><dt class="col-4">Hostname</dt><dd class="col-8 text-monospace">82.red-2-136-116.staticip.rima-tde.net</dd><dt class="col-4">Provider</dt><dd class="col-8 text-monospace">Telefonica De Espana S.a.u.</dd><dt class="col-4">ASN</dt><dd class="col-8 text-monospace">3352</dd> </dl>
# </div>
# <div class="mapael mt-4" id="geoMap">
# <div class="map position-relative"></div>
# </div>
# </div>

# %%
sopa.find('div', class_='mt-4')
# Out:
# <div class="col-xl-2 col-md-3 d-flex align-items-end mt-md-0 mt-4">
# <button class="btn btn-primary d-flex justify-content-center align-items-center w-md-100" id="geoBtn">Find</button>
# </div>

# %%
sopa.find('div', {'id': 'geoResult', 'class': 'mt-4'})
# Out:
# <div class="mt-4" id="geoResult">
# <div class="bg-light medium rounded p-3">
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mb-2">Location</p> <dl class="row mb-0">
# <dt class="col-4">City</dt><dd class="col-8 text-monospace">Madrid</dd><dt class="col-4">Region</dt><dd class="col-8 text-monospace">Madrid (M)</dd><dt class="col-4">Postal code</dt><dd class="col-8 text-monospace">28006</dd><dt class="col-4">Country</dt><dd class="col-8 text-monospace">Spain (ES)</dd><dt class="col-4">Continent</dt><dd class="col-8 text-monospace">Europe (EU)</dd><dt class="col-4">Coordinates</dt><dd class="col-8 text-monospace">40.4163 (lat) / -3.6934 (long)</dd><dt class="col-4">Time</dt><dd class="col-8 text-monospace">2023-02-07 11:53:03 (Europe/Madrid)</dd> </dl>
# <p class="small text-uppercase text-muted font-weight-semi-bold line-height-headings mt-4 mb-2">Network</p>
# <dl class="row mb-0">
# <dt class="col-4">IP address</dt><dd class="col-8 text-monospace">2.136.116.82</dd><dt class="col-4">Hostname</dt><dd class="col-8 text-monospace">82.red-2-136-116.staticip.rima-tde.net</dd><dt class="col-4">Provider</dt><dd class="col-8 text-monospace">Telefonica De Espana S.a.u.</dd><dt class="col-4">ASN</dt><dd class="col-8 text-monospace">3352</dd> </dl>
# </div>
# <div class="mapael mt-4" id="geoMap">
# <div class="map position-relative"></div>
# </div>
# </div>

# %%
tabla=sopa.find('div', {'id': 'geoResult', 'class': 'mt-4'})

# %%
tabla.find_all('dd')
# Out:
# [<dd class="col-8 text-monospace">Madrid</dd>,
#  <dd class="col-8 text-monospace">Madrid (M)</dd>,
#  <dd class="col-8 text-monospace">28006</dd>,
#  <dd class="col-8 text-monospace">Spain (ES)</dd>,
#  <dd class="col-8 text-monospace">Europe (EU)</dd>,
#  <dd class="col-8 text-monospace">40.4163 (lat) / -3.6934 (long)</dd>,
#  <dd class="col-8 text-monospace">2023-02-07 11:53:03 (Europe/Madrid)</dd>,
#  <dd class="col-8 text-monospace">2.136.116.82</dd>,
#  <dd class="col-8 text-monospace">82.red-2-136-116.staticip.rima-tde.net</dd>,
#  <dd class="col-8 text-monospace">Telefonica De Espana S.a.u.</dd>,
#  <dd class="col-8 text-monospace">3352</dd>]

# %%
tabla.find_all('dd')[0].text
# Out:
# 'Madrid'

# %%
[e.text for e in tabla.find_all('dd')]
# Out:
# ['Madrid',
#  'Madrid (M)',
#  '28006',
#  'Spain (ES)',
#  'Europe (EU)',
#  '40.4163 (lat) / -3.6934 (long)',
#  '2023-02-07 11:53:03 (Europe/Madrid)',
#  '2.136.116.82',
#  '82.red-2-136-116.staticip.rima-tde.net',
#  'Telefonica De Espana S.a.u.',
#  '3352']

# %%
conexion=[e.text for e in tabla.find_all('dd')]

# %%
# creo una funcion para todo el proceso, segun ip


def encontrar(ip):
    
    url = f'https://tools.keycdn.com/geo?host={ip}'
    
    html = req.get(url).text

    sopa = bs(html, 'html.parser')
    
    tabla=sopa.find('div', {'id': 'geoResult', 'class': 'mt-4'})
    
    conexion=[e.text for e in tabla.find_all('dd')]
    
    return conexion

# %%
encontrar('168.123.4.5')
# Out:
# ['Guam (GU)',
#  'Oceania (OC)',
#  '13.4786 (lat) / 144.8183 (long)',
#  '2023-02-07 21:00:57 (Pacific/Guam)',
#  '168.123.4.5',
#  '168.123.4.5',
#  'UNIVERSITY-GUAM',
#  '395400']

# %%
encontrar('46.222.34.200')
# Out:
# ['Spain (ES)',
#  'Europe (EU)',
#  '40.4172 (lat) / -3.684 (long)',
#  '2023-02-07 12:01:14 (Europe/Madrid)',
#  '46.222.34.200',
#  '46.222.34.200',
#  'Xtra Telecom S.A.',
#  '15704']

# %% [markdown]
# ### Ejemplo LinkedIn

# %%
url='https://www.linkedin.com/jobs/search/?currentJobId=3443970867&keywords=analista%20de%20datos'

# %%
html = req.get(url).text

sopa = bs(html, 'html.parser')

# %%
tarjetas = sopa.find('ul', class_='jobs-search__results-list')

type(tarjetas)
# Out:
# bs4.element.Tag

# %%
len(tarjetas.find_all('li'))
# Out:
# 25

# %%
curro=tarjetas.find_all('li')[0]

titulo=curro.find('h3').text.strip()

empresa = curro.find('h4').text.strip()

link_curro = curro.find('a').attrs['href']

link_comp = curro.find('h4').find('a').attrs['href']

pais = curro.find('span', class_="job-search-card__location").text.strip()

fecha = curro.find('time').attrs['datetime']

# %%
{'titulo': titulo,

'empresa': empresa,

'link_curro': link_curro,

'link_comp': link_comp, 

'pais': pais, 

'fecha': fecha}
# Out:
# {'titulo': 'Data Analyst',
#  'empresa': 'InterEx Group',
#  'link_curro': 'https://www.linkedin.com/jobs/view/data-analyst-at-interex-group-3453164950?refId=srhaF%2BHifNlLSQMm6c9gpA%3D%3D&trackingId=OPVfJmuhCJd9HsSSai1FVg%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card',
#  'link_comp': 'https://uk.linkedin.com/company/interex-group?trk=public_jobs_jserp-result_job-search-card-subtitle',
#  'pais': 'United States',
#  'fecha': '2023-01-27'}

# %%
def linkedin(num_pages, keywords, loc, n_secs):

    URL = 'https://www.linkedin.com/jobs/search/'

    data = []

    for i in range(num_pages):

        scrape_url = ''.join([URL,  # url principal
                              f'?keywords={keywords}',
                              '&geoId=105646813'
                              f'&location={loc}',
                              f'&f_TPR={n_secs}',
                              f'&start={i*25}'
                             ])

        print(scrape_url)

        html = req.get(url).text

        sopa = bs(html, 'html.parser')

        tarjetas = sopa.find('ul', class_='jobs-search__results-list')


        for curro in tarjetas:  # bucle sobre los li, las tarjetas de cada curro
            
            try:
                titulo=curro.find('h3').text.strip()

                empresa = curro.find('h4').text.strip()

                link_curro = curro.find('a').attrs['href']

                link_comp = curro.find('h4').find('a').attrs['href']

                pais = curro.find('span', class_="job-search-card__location").text.strip()

                fecha = curro.find('time').attrs['datetime']


                data.append({'titulo': titulo,
                             'empresa': empresa,
                             'link_curro': link_curro,
                             'link_comp': link_comp, 
                             'pais': pais, 
                             'fecha': fecha})
                
            except:
                continue

    return pd.DataFrame(data)

# %%
df=linkedin(5, 'analista%20de%20datos', 'spain', 30000)
# Out:
# https://www.linkedin.com/jobs/search/?keywords=analista%20de%20datos&geoId=105646813&location=spain&f_TPR=30000&start=0
# https://www.linkedin.com/jobs/search/?keywords=analista%20de%20datos&geoId=105646813&location=spain&f_TPR=30000&start=25
# https://www.linkedin.com/jobs/search/?keywords=analista%20de%20datos&geoId=105646813&location=spain&f_TPR=30000&start=50
# https://www.linkedin.com/jobs/search/?keywords=analista%20de%20datos&geoId=105646813&location=spain&f_TPR=30000&start=75
# https://www.linkedin.com/jobs/search/?keywords=analista%20de%20datos&geoId=105646813&location=spain&f_TPR=30000&start=100

# %%
df.head()
# Out:
#                       titulo            empresa  \
# 0               Data Analyst      InterEx Group
# 1               Data Analyst            P.volve
# 2  Data Analyst ( US REMOTE)             Zip Co
# 3               Data Analyst  Cybernetic Search
# 4               Data Analyst         Convergenz
#
#                                           link_curro  \
# 0  https://www.linkedin.com/jobs/view/data-analys...
# 1  https://www.linkedin.com/jobs/view/data-analys...
# 2  https://www.linkedin.com/jobs/view/data-analys...
# 3  https://www.linkedin.com/jobs/view/data-analys...
# 4  https://www.linkedin.com/jobs/view/data-analys...
#
#                                            link_comp  \
# 0  https://uk.linkedin.com/company/interex-group?...
# 1  https://www.linkedin.com/company/p-volve?trk=p...
# 2  https://au.linkedin.com/company/zip-co-limited...
# 3  https://www.linkedin.com/company/cybernetic-se...
# 4  https://www.linkedin.com/company/convergenz?tr...
#
#                               pais       fecha
# 0                    United States  2023-01-27
# 1                    United States  2023-01-26
# 2                    United States  2023-01-23
# 3  New York City Metropolitan Area  2023-01-24
# 4                       McLean, VA  2023-02-01

# %%
from IPython.display import HTML

HTML(df.to_html(render_links=True))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titulo</th>
#       <th>empresa</th>
#       <th>link_curro</th>
#       <th>link_comp</th>
#       <th>pais</th>
#       <th>fecha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Data Analyst</td>
#       <td>InterEx Group</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-interex-group-3453164950?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=d%2BCq7y%2BcYM3k8ZP5XBDLLg%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-interex-group-3453164950?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=d%2BCq7y%2BcYM3k8ZP5XBDLLg%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://uk.linkedin.com/company/interex-group?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://uk.linkedin.com/company/interex-group?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>United States</td>
#       <td>2023-01-27</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Data Analyst</td>
#       <td>P.volve</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-p-volve-3452239869?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=FAL%2B4OMKmG1vJD1GDfxnJw%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-p-volve-3452239869?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=FAL%2B4OMKmG1vJD1GDfxnJw%3D%3D&amp;position=2&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/p-volve?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/p-volve?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>United States</td>
#       <td>2023-01-26</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Data Analyst ( US REMOTE)</td>
#       <td>Zip Co</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-us-remote-at-zip-co-3447058496?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=yX11buyztLnWPGxdmpmtQQ%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-us-remote-at-zip-co-3447058496?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=yX11buyztLnWPGxdmpmtQQ%3D%3D&amp;position=3&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://au.linkedin.com/company/zip-co-limited?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://au.linkedin.com/company/zip-co-limited?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>United States</td>
#       <td>2023-01-23</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Data Analyst</td>
#       <td>Cybernetic Search</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-cybernetic-search-3450545266?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=ymNisN0KVgDj0U2HF5kvvA%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-cybernetic-search-3450545266?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=ymNisN0KVgDj0U2HF5kvvA%3D%3D&amp;position=4&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/cybernetic-search?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/cybernetic-search?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>New York City Metropolitan Area</td>
#       <td>2023-01-24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Data Analyst</td>
#       <td>Convergenz</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-convergenz-3464130875?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=FWHGKzCQzHgn%2BslpnXabNA%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-convergenz-3464130875?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=FWHGKzCQzHgn%2BslpnXabNA%3D%3D&amp;position=5&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/convergenz?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/convergenz?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>McLean, VA</td>
#       <td>2023-02-01</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Data Analyst</td>
#       <td>Forward Progress Staffing</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-forward-progress-staffing-3457159658?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=W%2BHlCG4AtlYi1qikpei88g%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-forward-progress-staffing-3457159658?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=W%2BHlCG4AtlYi1qikpei88g%3D%3D&amp;position=6&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/forward-progress-staffing?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/forward-progress-staffing?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>New York City Metropolitan Area</td>
#       <td>2023-01-27</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Data Analyst</td>
#       <td>Irvine Technology Corporation</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-irvine-technology-corporation-3458209888?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=ZAKaudskP4%2B1hR8uidp7Zw%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-irvine-technology-corporation-3458209888?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=ZAKaudskP4%2B1hR8uidp7Zw%3D%3D&amp;position=7&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/irvine-technology-corporation?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/irvine-technology-corporation?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>Arlington, TX</td>
#       <td>2023-02-01</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Data Analyst</td>
#       <td>Creyon Bio</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-creyon-bio-3455692801?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=94LEZjkfAPuLW3Hj0HVM7g%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-creyon-bio-3455692801?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=94LEZjkfAPuLW3Hj0HVM7g%3D%3D&amp;position=8&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card</a></td>
#       <td><a href="https://www.linkedin.com/company/creyonbio?trk=public_jobs_jserp-result_job-search-card-subtitle" target="_blank">https://www.linkedin.com/company/creyonbio?trk=public_jobs_jserp-result_job-search-card-subtitle</a></td>
#       <td>San Diego Metropolitan Area</td>
#       <td>2023-01-31</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Data Analyst</td>
#       <td>Trustpoint.One</td>
#       <td><a href="https://www.linkedin.com/jobs/view/data-analyst-at-trustpoint-one-3450136985?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&trackingId=kBiOoB07NKJVqqrYhZG0Gw%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card" target="_blank">https://www.linkedin.com/jobs/view/data-analyst-at-trustpoint-one-3450136985?refId=jVaopuO0XAkrmPVG4yWJSg%3D%3D&amp;trackingId=kBiOoB07NKJVqqrYhZG0Gw%3D%3D&amp;posi
